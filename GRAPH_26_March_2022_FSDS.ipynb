# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
np.random.randn(1000)
# Out:
# array([-1.01483801e+00,  1.68393207e+00, -9.80537275e-01,  4.79169092e-01,
#        -3.03349444e-01, -6.06149316e-01,  9.49195249e-01, -8.27894167e-01,
#         2.41023516e+00,  2.11935897e-01,  1.77244033e+00, -3.93048489e-01,
#        -1.52426706e+00,  4.64545903e-02,  4.45409834e-01, -4.51363540e-01,
#         1.66659794e+00,  2.00398105e+00, -7.16461468e-01, -3.10106778e-02,
#         1.79126270e+00,  1.58331204e+00, -2.76409238e-01,  2.11454616e+00,
#         4.15926419e-01, -2.56320495e-01,  1.44997339e+00,  7.96825178e-01,
#        -7.40835229e-01, -1.46529798e+00, -3.23073795e-01, -1.14179168e+00,
#        -1.51559510e+00,  5.88233018e-01,  1.49136096e-01,  1.66480492e+00,
#         2.17687358e-01,  1.04610648e-02,  1.06837050e-01, -1.86249773e-01,
#        -1.14115463e+00,  9.70861306e-01,  1.01750836e-01,  8.34390500e-02,
#         1.90818238e-02, -3.55157413e-01,  2.08130338e+00,  1.18643058e+00,
# ...

# %%
pd.DataFrame(np.random.randn(1000))
# Out:
#             0
# 0    0.511640
# 1    0.788154
# 2    1.289083
# 3   -0.230416
# 4    0.639156
# ..        ...
# 995  0.340464
# 996 -1.499331
# 997  2.217143
# 998  0.972072
# 999  1.015471
#
# [1000 rows x 1 columns]

# %%
pd.DataFrame(np.random.randn(1000),columns=['data'])
# Out:
#          data
# 0    0.218620
# 1    0.356810
# 2   -0.743163
# 3    0.041603
# 4   -1.677431
# ..        ...
# 995 -0.429567
# 996 -0.334806
# 997  0.345364
# 998 -0.266943
# 999 -2.389397
#
# [1000 rows x 1 columns]

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df
# Out:
#          data
# 0   -0.323659
# 1   -0.131794
# 2    0.888218
# 3   -0.171256
# 4    0.085721
# ..        ...
# 995  1.170695
# 996  1.354550
# 997 -0.270665
# 998 -0.687458
# 999 -0.585525
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range('2022/03/26',periods=1000))

# %%
df
# Out:
#                 data
# 2022-03-26  0.531209
# 2022-03-27 -0.424034
# 2022-03-28 -1.263533
# 2022-03-29  0.850022
# 2022-03-30  0.259227
# ...              ...
# 2024-12-15  0.239026
# 2024-12-16 -1.590749
# 2024-12-17 -0.141135
# 2024-12-18  0.029311
# 2024-12-19  1.785490
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df=pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df=df.drop("Id",axis=1) #id is column

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[0:1]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
df.iloc[0:1].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10)) #horizontal
# Out:
# <AxesSubplot:>

# %%
df.plot( kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df["SepalLengthCm"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["SepalLengthCm"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df["SepalLengthCm"].plot(kind="hist",orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.hist(figsize=(20,10),color='g')
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='g',alpha=0.5) #alpha gives intensity
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind="box",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
#horizontal line represents min and max Q1 and Q4 quartiles

# %%
mean = average
median=middle value
mode=most frequent value


Q1,Q2,Q3,Q4=RANGE VALUES  -  IQR INTER QUARTILE RANGE

Q1=25%
Q2=50%=MEDIAN
Q3=75%

# %%
df.plot(kind="box",figsize=(20,10),color='r')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="box",figsize=(20,10),color={'boxes':'g','whiskers':'r'},vert=False)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="area",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="area",figsize=(20,10),alpha=.5,stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="area",figsize=(20,10),alpha=.5,stacked=True)
# Out:
# <AxesSubplot:>

# %%
df

# %%
df.plot.scatter("SepalLengthCm","PetalLengthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter("SepalLengthCm","PetalWidthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x="PetalLengthCm",y="PetalWidthCm",c="SepalLengthCm")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter("PetalLengthCm","PetalWidthCm","SepalLengthCm")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x="PetalLengthCm",y="PetalWidthCm",c="SepalLengthCm",s=600)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x="PetalLengthCm",y="PetalWidthCm",c="SepalWidthCm",s=df['PetalWidthCm']*500)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.hexbin(x="PetalLengthCm",y="PetalWidthCm",gridsize=10,C="SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df1=df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cufflinks as cf

# %%
pip install chart_studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cf.go_offline() #sometimes if cufflink is not working
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="f743d406-b7c6-4c95-b3fd-07fc17661fe1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(x='SepalLengthCm', y='PetalLengthCm',mode='markers',kind="scatter")
# Out:
# <div>                            <div id="d64f2947-65c7-4fd3-8bc6-7507a95f4bbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers',size=3)
# Out:
# <div>                            <div id="420fcd90-080b-4ca5-a18e-ddebe0083772" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='SepalLengthCm',y='PetalLengthCm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 12
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="bfb10445-3e6d-446d-982a-87324810bda9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter3d',x='SepalLengthCm',y='SepalWidthCm', z='PetalLengthCm')
# Out:
# <div>                            <div id="fbbebb01-f30b-491e-ac31-8b393bd5353a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='scatter3d',x='SepalLengthCm',y='SepalWidthCm', z='PetalLengthCm')
# Out:
# <div>                            <div id="d57ad59b-f51e-4d7c-beac-9d5bb9119508" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter3d',x='SepalLengthCm',y='SepalWidthCm', z='PetalLengthCm')
# Out:
# <div>                            <div id="c06365e5-1f98-45d4-b15f-8cbfeb10cbf5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble3d',x='SepalLengthCm',y='SepalWidthCm', z='PetalLengthCm',size='PetalWidthCm')
# Out:
# <div>                            <div id="cd12710c-8486-42a0-8299-5ae276194aad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
try to explore map graph and try to show and example(2,3)
